# %%
import pandas as pd
df=pd.read_csv("/content/ARP Poison,flood attack Dataset.csv")

# %%
df.drop_duplicates()
# Out:
#        switch_id  in_port     outport  src_mac_addr(eth)  src_mac_addr(arp)  \
# 0              5        1  4294967291  00:00:00:00:00:07  00:00:00:00:00:07
# 1              2        3  4294967291  00:00:00:00:00:07  00:00:00:00:00:07
# 2              4        4  4294967291  00:00:00:00:00:07  00:00:00:00:00:07
# 3              3        4  4294967291  00:00:00:00:00:07  00:00:00:00:00:07
# 4              1        1  4294967291  00:00:00:00:00:07  00:00:00:00:00:07
# ...          ...      ...         ...                ...                ...
# 42576         10        4  4294967291  18:6b:81:aa:f9:ec  80:6b:10:b1:a5:e7
# 42577          5        4  4294967291  5d:ef:5b:d3:e3:e3  9b:96:9d:20:a3:ef
# 42578          2        1  4294967291  cf:e8:8f:60:84:ef  b8:08:73:3d:47:55
# 42579          4        4  4294967291  08:79:32:53:af:42  9b:54:1d:9f:bf:fb
# 42580          9        4  4294967291              f9:da                NaN
#
# ...

# %%
from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()


df['src_mac_addr(eth)']= label_encoder.fit_transform(df['src_mac_addr(eth)'])

# %%
from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()

df['src_mac_addr(arp)']= label_encoder.fit_transform(df['src_mac_addr(arp)'])

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()


df['dst_mac_addr(eth)']= label_encoder.fit_transform(df['dst_mac_addr(eth)'])

# %%
from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()


df['dst_mac_addr(arp)']= label_encoder.fit_transform(df['dst_mac_addr(arp)'])

# %%
from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()


df['src_ip(arp)']= label_encoder.fit_transform(df['src_ip(arp)'])

# %%
from sklearn import preprocessing


label_encoder = preprocessing.LabelEncoder()


df['dst_ip(arp)']= label_encoder.fit_transform(df['dst_ip(arp)'])

# %%
X = df.values
y = df['total_time'].values

# %%
df['packet_in_count']=df['packet_in_count'].fillna(0)

# %%
df['total_time']=df['total_time'].fillna(0)

# %%
df=df.fillna(0)

# %%
display(df)
# Out:
#        switch_id  in_port     outport  src_mac_addr(eth)  src_mac_addr(arp)  \
# 0              5        1  4294967291                  6                  6
# 1              2        3  4294967291                  6                  6
# 2              4        4  4294967291                  6                  6
# 3              3        4  4294967291                  6                  6
# 4              1        1  4294967291                  6                  6
# ...          ...      ...         ...                ...                ...
# 42576         10        4  4294967291                 42                120
# 42577          5        4  4294967291                 87                133
# 42578          2        1  4294967291                182                164
# 42579          4        4  4294967291                 28                132
# 42580          9        4  4294967291                211                214
#
# ...

# %%
df.drop(['Protocol','rtt (avg)'],axis=1)
# Out:
#        switch_id  in_port     outport  src_mac_addr(eth)  src_mac_addr(arp)  \
# 0              5        1  4294967291                  6                  6
# 1              2        3  4294967291                  6                  6
# 2              4        4  4294967291                  6                  6
# 3              3        4  4294967291                  6                  6
# 4              1        1  4294967291                  6                  6
# ...          ...      ...         ...                ...                ...
# 42576         10        4  4294967291                 42                120
# 42577          5        4  4294967291                 87                133
# 42578          2        1  4294967291                182                164
# 42579          4        4  4294967291                 28                132
# 42580          9        4  4294967291                211                214
#
# ...

# %%
X = df.values
y = df['total_time'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Training the K-NN model on the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)


y_pred = classifier.predict(X_test)


from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
ac = accuracy_score(y_test, y_pred)

# %%
print(ac)
# Out:
# 0.9644240929904896

# %%
print(cm)
# Out:
# [[  28    0    0 ...    0    0    0]
#  [   0   46    0 ...    0    0    0]
#  [   0    0   38 ...    0    0    0]
#  ...
#  [   0    0    0 ...  152    0    0]
#  [   0    3    0 ...    0 1112    0]
#  [   0    0    0 ...    2    0 2595]]
